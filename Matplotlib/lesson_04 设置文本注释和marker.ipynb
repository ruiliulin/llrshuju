# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - 有时候，我们想要在一些关键点上重点标记出来。那么我们可以通过设置 marker 来实现

# %%
# np.linspace(a, b, c)将区间ab按c等分
x = np.linspace(0, 20, 50)
y = np.sin(x)
plt.plot(x, y, marker='o', markerfacecolor='r', markersize=6, markeredgecolor='r')

# %% [markdown]
# ### 设置注释文本：
# - 有时候需要在图形中的某个点标记或者注释一下
# - 我们可以使用 plt.annotate(text,xy,xytext,arrowprops={}) 来实现
#     - 其中 text 是注释的文本， xy 是需要注释的点的坐标， xytext 是注释文本的坐标， arrowprops 是箭头的样式属性

# %%
plt.plot(np.sin(np.arange(20)), marker='o')
# arrowprops{width:箭身宽度，headwidth:箭头宽度，headlength:箭头长度，shrink:整个箭头与两头数据之间的空隙, facecolor:箭身颜色 }
plt.annotate('(0, 0)', xy=(0,0), xytext=(-0.75, -0.5), 
             arrowprops={"width":4, "headwidth":7, "headlength":7, "shrink":0.15, "facecolor":'r', "edgecolor":'b'})
# Out:
# Text(-0.75,-0.5,'(0, 0)')

# %%
y = np.sin(np.arange(20))
plt.plot(y, marker='o')
# enumerate:返回循环的下标值（索引）
for index,value in enumerate(y):
    plt.annotate('(%d, %.2f)'%(index, value), xy=(index, value), xytext=(index-0.1, value-0.1))

# %% [markdown]
# # 笔记：
# 1. plt.plot的时候，可以通过marker参数设置坐标点的样式。markerfacecolor代表的是点的颜色，markeredgecolor代表的是点的边界的颜色，markersize代表的是点的大小。
# 2. plt.annotate(text,xy,xytext,arrowprops)是用来做文本注释的，text代表的是需要注释的文本，xy代表的是需要注释的坐标点，xytext代表的是文本的坐标点，arrowprops代表的是箭头的一些属性。
# 3. annotate的官方文档：https://matplotlib.org/api/_as_gen/matplotlib.pyplot.annotate.html#matplotlib.pyplot.annotate
